# %% [markdown]
# # Sector economics
# Hold the measured lift fixed and change only gross margin: the break-even lift each sector needs.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))
from retaillab.analysis import analyze
from retaillab.data import load_experiment
from retaillab.finance import break_even_lift, load_margins

data, source = load_experiment()
readout = analyze(data)
margins = load_margins()
{
    sector: {
        "gross_margin": values["gross_margin"],
        "break_even_lift": break_even_lift(0.18, readout.baseline_revenue, values["gross_margin"]),
        "observed_lift": readout.revenue_lift,
    }
    for sector, values in margins["margins"].items()
}
