# %% [markdown]
# # Email ROI
# Estimate incremental revenue and contribution after contact cost.

# %%
from retaillab.demo import demo_email
from retaillab.finance import pnl

pnl(demo_email(), .4, .18)
