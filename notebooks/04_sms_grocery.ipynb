# %% [markdown]
# # Grocery economics
# Compare break-even lift under different sector margin benchmarks.

# %%
from retaillab.finance import break_even_lift

{sector: break_even_lift(.2, 2.0, margin) for sector, margin in {'apparel': .45, 'grocery': .28}.items()}
