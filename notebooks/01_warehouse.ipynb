# %% [markdown]
# # RetailLab warehouse
# Build the star schema from `sql/warehouse.sql`. Uses Hillstrom and Damodaran when `data/raw` is populated, otherwise synthetic data and placeholder margins.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))
from retaillab.data import load_experiment
from retaillab.finance import load_margins
from retaillab.warehouse import build_warehouse, table_counts

data, source = load_experiment()
margins = load_margins()
connection = build_warehouse(":memory:", data, margins, contact_cost=0.18)
print(source, margins["source"], margins["as_of"])
table_counts(connection)

# %%
connection.execute("SELECT * FROM mart_pnl").df()
