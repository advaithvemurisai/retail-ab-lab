# %% [markdown]
# # RetailLab warehouse
# Build a deterministic demo mart when licensed raw files are not available.

# %%
from retaillab.demo import demo_email
from retaillab.warehouse import build_warehouse

data = demo_email(1000)
build_warehouse("../data/notebook.duckdb", {"mart_experiment": data})
data.head()
