# %% [markdown]
# # Which e-mail should roll out?
# The store-promotion dataset was dropped; this notebook compares Hillstrom's two creatives against no e-mail with BH correction, as on the app's "Which e-mail" page.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))
from retaillab.data import DESIGN, load_experiment
from retaillab.estimate import pairwise_arms

data, source = load_experiment()
data.groupby("arm")[["visit", "conversion", "revenue"]].mean()

# %%
pairwise_arms(data, list(DESIGN), "revenue")
